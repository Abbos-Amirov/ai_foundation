# %% [markdown]
# <a href="https://colab.research.google.com/github/Abbos-Amirov/ai_foundation/blob/main/numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install numpy

# %%
import numpy as np

arr = np.array ([1,2,3,4,5,])
print('array:',arr)
# Out:
# array: [1 2 3 4 5]

# %% [markdown]
# arr2 = np.array ([[1,2,3,4,5,], [1,3,4,5,6]])
# print('array:',arr2)
# arr2.shape

# %%
a = np.array([1, 2, 3])

b = a.astype(float)

print(b)
# Out:
# [1. 2. 3.]

# %%
z = np.zeros((2,3))

print(z)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]]

# %%
a = np.array([[1,2],[3,4]])

print(a.ndim)
# Out:
# 2
